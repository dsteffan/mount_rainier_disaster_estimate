# %% [markdown]
# # Pierce Data Cleaning
# ---
#
# This notebook details the process by which the Pierce Tax Parcel data was cut down and cleaned. The dataframe in question had over 300,000 rows and 35 columns, which made it too large for GitHub to handle. The resulting dataframe was cut down by nearly half. Note that in order to run through this code again, you will have to download the raw data from the Pierce County Assessor's office. Alternatively, just continue with the tax_parcels_trimmed.csv, which is used for the rest of the analysis and will fit on GitHub.

# %% [markdown]
# ### Importing
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt
import pysal.lib.io
import os
import time
# Out:
# /Users/derek/anaconda3/lib/python3.7/site-packages/pysal/lib/weights/util.py:19: UserWarning: geopandas not available. Some functionality will be disabled.
#   warn('geopandas not available. Some functionality will be disabled.')
# /Users/derek/anaconda3/lib/python3.7/site-packages/pysal/model/spvcm/abstracts.py:10: UserWarning: The `dill` module is required to use the sqlite backend fully.
#   from .sqlite import head_to_sql, start_sql

# %%
raw = pd.read_csv("../data/Tax_Parcels.csv")
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3044: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Files over 100MB cannot be uploaded to GitHub, so the 
# Tax Parcels data will have to be trimmed down slightly.

print(os.path.getsize("../data/Tax_Parcels.csv") / 1_000_000, "MB")
# Out:
# 150.901018 MB

# %%
# Open the volcanic hazards shape file

hazard = pysal.lib.io.open("../data/Volcanic_Hazards/Volcanic_Hazards.shp")

hazard

# %%
raw.shape
# Out:
# (327319, 35)

# %%
raw.head()
# Out:
#    OBJECTID  TaxParcelNumber TaxParcelType  TaxParcelLevel TaxParcelUnit  \
# 0      3001         21247005   Base Parcel             0.0
# 1      3002         21247006   Base Parcel             0.0
# 2      3003         21247007   Base Parcel             0.0
# 3      3004         21247700   Base Parcel             0.0
# 4      3005         21247701   Base Parcel             0.0
#
#   TaxParcelUnitType             EffectiveDate RetiredDate  \
# 0                                         NaN         NaN
# 1               NaN  2014-10-29T00:00:00.000Z         NaN
# 2                    2014-10-29T00:00:00.000Z         NaN
# 3                                         NaN         NaN
# 4                                         NaN         NaN
#
#    TaxParcelMultiPartCount  SubtypeCD  ...  \
# 0                      1.0          0  ...
# 1                      1.0          0  ...
# 2                      1.0          0  ...
# 3                      1.0          0  ...
# 4                      1.0          0  ...
#
#                                    Legal_Description Exemption_Code   RTSQQ  \
# 0  Section 24  Township 21  Range 00  Quarter 34 ...            EXR  212434
# 1  Section 24  Township 21  Range 00  Quarter 33 ...            NaN  212433
# 2  Section 24  Township 21  Range 00  Quarter 33 ...            NaN  212433
# 3  Section 24 Township 21 Range 00 Quarter 33 : 2...            NaN  212433
# 4  Section 24 Township 21 Range 00 Quarter 33 : 2...            NaN  212433
#
#    X_Coordinate Y_Coordinate  Longitude  Latitude    MapLegend    Shape__Area  \
# 0  1.081288e+06  721057.9755 -122.75325  47.28867  Base Parcel   38758.018311
# 1  1.080163e+06  720458.5894 -122.75771  47.28694  Base Parcel  345604.122986
# 2  1.081042e+06  720375.4829 -122.75416  47.28678  Base Parcel  133528.313354
# 3  1.080063e+06  720851.0629 -122.75815  47.28801  Base Parcel   60097.457336
# 4  1.080827e+06  720849.5547 -122.75508  47.28806  Base Parcel  122531.592957
#
#    Shape__Length
# 0    1141.837123
# 1    3638.028072
# 2    2089.154656
# 3    1243.548915
# 4    2293.364640
#
# [5 rows x 35 columns]

# %%
raw.isna().sum()
# Out:
# OBJECTID                        0
# TaxParcelNumber                 0
# TaxParcelType                   0
# TaxParcelLevel               3720
# TaxParcelUnit                3822
# TaxParcelUnitType           15485
# EffectiveDate              298296
# RetiredDate                327120
# TaxParcelMultiPartCount     28132
# SubtypeCD                       0
# TaxParcelComment            23237
# EditDate                        6
# Delivery_Address               38
# City_State                      0
# Zipcode                      2802
# Site_Address                    0
# Business_Name              285468
# Land_Acres                      0
# Land_Value                      0
# Improvement_Value               0
# Taxable_Value                   0
# Use_Code                        3
# Tax_Area_Code                   0
# Landuse_Description             3
# Tax_Senior_Exemption       316122
# Legal_Description               7
# Exemption_Code             311561
# RTSQQ                           0
# X_Coordinate                    0
# Y_Coordinate                    0
# Longitude                       0
# Latitude                        0
# MapLegend                       0
# Shape__Area                     0
# Shape__Length                   0
# dtype: int64

# %% [markdown]
# ## Pruning the Data
# ---

# %%
# There are 35 columns in the Tax parcel data, and we need to 
# cut out 50MB out of the csv, about 33% of the total size on
# disk. So to get under the 100MB threshold for GitHub, we need 
# to get rid of 33% of our columns, or about 11-12 columns.

# These columns have either useless data for our purposes, or
# too many null values to be of use. 

trim = ["MapLegend", "RTSQQ", "Exemption_Code", "Legal_Description", 
        "Business_Name", "TaxParcelComment", "TaxParcelMultiPartCount",
        "SubtypeCD", "TaxParcelUnit", "Tax_Senior_Exemption", "Use_Code",
        "TaxParcelLevel", "OBJECTID", "RetiredDate", "EffectiveDate"]

# %%
df = raw.drop(columns = trim)

# %%
df.to_csv("../data/Tax_Parcels_Trimmed.csv", index = False)

# %%
# reimport the dataframe here if you wish to run through the
# visualizations and do not have the raw data from the
# Pierce County Assessor's office.

df = pd.read_csv("../data/Tax_Parcels_Trimmed.csv")

# %%
# confirming that the new csv will fit on GitHub

print(os.path.getsize("../data/Tax_Parcels_Trimmed.csv") / 1_000_000, "MB")
# Out:
# 80.898706 MB

# %%
df.head()
# Out:
#    TaxParcelNumber TaxParcelType TaxParcelUnitType                  EditDate  \
# 0         21247005   Base Parcel                    1998-07-24T00:00:00.000Z
# 1         21247006   Base Parcel               NaN  2014-11-26T12:23:33.000Z
# 2         21247007   Base Parcel                    2014-11-26T12:23:33.000Z
# 3         21247700   Base Parcel                    1996-01-23T00:00:00.000Z
# 4         21247701   Base Parcel                    1996-01-23T00:00:00.000Z
#
#         Delivery_Address        City_State     Zipcode  \
# 0  UNKNOWN PARTY ADDRESS  UNKNOWN CITY, WA         NaN
# 1    3211 MCEWAN ROAD NW       LAKEBAY, WA       98349
# 2    3211 MCEWAN ROAD NW       LAKEBAY, WA       98349
# 3             PO BOX 670       LAKEBAY, WA  98349-0670
# 4             PO BOX 670       LAKEBAY, WA  98349-0670
#
#              Site_Address  Land_Acres  Land_Value  Improvement_Value  \
# 0        XXX 34TH STCT NW      0.0000           0                  0
# 1       3211 MCEWAN RD NW      7.6300      364000            1129400
# 2       3209 MCEWAN RD NW      2.8700      251400                  0
# 3  XXX Undetermined Situs      1.3174       33900                  0
# 4      16407 33RD STCT NW      2.7100      251200             563200
#
#    Taxable_Value  Tax_Area_Code      Landuse_Description  X_Coordinate  \
# 0              0            471                  UNKNOWN  1.081288e+06
# 1        1493400            471   SINGLE FAMILY DWELLING  1.080163e+06
# 2         251400            471  VACANT LAND UNDEVELOPED  1.081042e+06
# 3          33900            471  VACANT LAND UNDEVELOPED  1.080063e+06
# 4         814400            471   SINGLE FAMILY DWELLING  1.080827e+06
#
#    Y_Coordinate  Longitude  Latitude    Shape__Area  Shape__Length
# 0   721057.9755 -122.75325  47.28867   38758.018311    1141.837123
# 1   720458.5894 -122.75771  47.28694  345604.122986    3638.028072
# 2   720375.4829 -122.75416  47.28678  133528.313354    2089.154656
# 3   720851.0629 -122.75815  47.28801   60097.457336    1243.548915
# 4   720849.5547 -122.75508  47.28806  122531.592957    2293.364640

# %% [markdown]
# ## Plotting
# ---

# %%
plt.figure(figsize = (12,12))
plt.scatter(df["X_Coordinate"], df["Y_Coordinate"], alpha = 0.1, s = 1)

plt.title("Tax Parcels by Coordinates");

# %%
plt.figure(figsize = (12,12))
plt.scatter(df["Longitude"], df["Latitude"], alpha = 0.1, s = 1)

plt.title("Tax Parcels by Latitude and Longitude");

# %% [markdown]
# > These two plots show that the X/Y Coordinate columns and Lat/Long columns plot the same way. I'm not sure what units the X/Y Coordinates are in, but they are the same units as the volcanic hazards shapefile, as demonstrated below.

# %%
plt.figure(figsize = (12,12))
plt.scatter(df["X_Coordinate"], df["Y_Coordinate"], alpha = 0.1, s = 1)
shp = hazard
for poly in range(len(list(shp))):
    x = []
    y = []
    for i in shp[poly].vertices:
        x.append(i[0])
        y.append(i[1])

    plt.scatter(x, y, c = "crimson", s = 1)
    plt.xlim(df["X_Coordinate"].min(), df["X_Coordinate"].max())
    plt.ylim(shp.header['BBOX Ymin'], df["Y_Coordinate"].max())
    
plt.title("Tax Parcels overlaid by Volcanic Hazards");

# %%
# Isolate just the Latitude and longitude coordinates 
# and export to separate .csv for use in GIS reader.

df[["Longitude", "Latitude"]].to_csv("../data/lat_long.csv")

# %%
# Function that will loop through all the polygons in the shapefile and 
# return whether or not the coordinates are contained in the shapefile.

def contains(x, y, shp_file = hazard):

    for j in range(len(list(shp_file))):
        if shp_file[j].contains_point((x, y)):
            return True

    return False

# %%
contains(1325000, 530000)
# Out:
# True

# %%
df["at_risk"] = False

# %%
# Iterate through every coordinate and and check to see if it is
# in the path of the lahar flows by checking if it is contained
# within the polygons from the shapefile. 

# Will take a while to run on the full dataset.

n_rows = len(df)
checkpoint = 1000

# estimate based on roughly 27 seconds for 1000 rows
print(f"Estimated {round(((n_rows / 1000) * 27) / 60, 2)} minutes for {n_rows} rows.")

then = time.time()
last = then

times = []

for i in range(n_rows):
 
    df["at_risk"][i] = contains(df["X_Coordinate"][i], df["Y_Coordinate"][i])
    
    if i % checkpoint == 0 and i != 0:
        
        current = time.time() - last
        times.append(current)
        
        print(i, f"rows completed in {round(current, 2)} seconds, estimated",
              round(((n_rows - i) / checkpoint * current) / 60, 2),
              "minutes remaining")
        
        last = time.time()
        
print(f"\nCompleted {n_rows} rows in {round(((time.time() - then) / 60), 2)} minutes")
# Out:
# Estimated 147.29 minutes for 327319 rows.
# 1000 rows completed in 27.49 seconds, estimated 149.48 minutes remaining
# 2000 rows completed in 27.27 seconds, estimated 147.85 minutes remaining
# 3000 rows completed in 27.07 seconds, estimated 146.33 minutes remaining
# 4000 rows completed in 27.1 seconds, estimated 146.01 minutes remaining
# 5000 rows completed in 27.13 seconds, estimated 145.76 minutes remaining
# 6000 rows completed in 27.25 seconds, estimated 145.92 minutes remaining
# 7000 rows completed in 27.2 seconds, estimated 145.21 minutes remaining
# 8000 rows completed in 27.09 seconds, estimated 144.16 minutes remaining
# 9000 rows completed in 27.09 seconds, estimated 143.7 minutes remaining
# 10000 rows completed in 27.13 seconds, estimated 143.47 minutes remaining
# 11000 rows completed in 27.03 seconds, estimated 142.52 minutes remaining
# 12000 rows completed in 27.14 seconds, estimated 142.64 minutes remaining
# 13000 rows completed in 27.36 seconds, estimated 143.33 minutes remaining
# 14000 rows completed in 27.07 seconds, estimated 141.38 minutes remaining
# 15000 rows completed in 27.85 seconds, estimated 144.95 minutes remaining
# 16000 rows completed in 27.6 seconds, estimated 143.2 minutes remaining
# 17000 rows completed in 27.11 seconds, estimated 140.22 minutes remaining
# 18000 rows completed in 27.13 seconds, estimated 139.86 minutes remaining
# 19000 rows completed in 27.0 seconds, estimated 138.76 minutes remaining
# 20000 rows completed in 27.13 seconds, estimated 138.94 minutes remaining
# 21000 rows completed in 27.07 seconds, estimated 138.18 minutes remaining
# 22000 rows completed in 27.05 seconds, estimated 137.66 minutes remaining
# 23000 rows completed in 27.08 seconds, estimated 137.34 minutes remaining
# 24000 rows completed in 27.07 seconds, estimated 136.86 minutes remaining
# 25000 rows completed in 27.03 seconds, estimated 136.2 minutes remaining
# 26000 rows completed in 27.07 seconds, estimated 135.94 minutes remaining
# 27000 rows completed in 27.59 seconds, estimated 138.11 minutes remaining
# 28000 rows completed in 27.18 seconds, estimated 135.59 minutes remaining
# 29000 rows completed in 27.28 seconds, estimated 135.66 minutes remaining
# 30000 rows completed in 27.58 seconds, estimated 136.69 minutes remaining
# 31000 rows completed in 27.45 seconds, estimated 135.55 minutes remaining
# 32000 rows completed in 27.04 seconds, estimated 133.1 minutes remaining
# 33000 rows completed in 27.28 seconds, estimated 133.84 minutes remaining
# 34000 rows completed in 27.0 seconds, estimated 132.0 minutes remaining
# 35000 rows completed in 27.26 seconds, estimated 132.81 minutes remaining
# 36000 rows completed in 27.07 seconds, estimated 131.45 minutes remaining
# 37000 rows completed in 27.14 seconds, estimated 131.3 minutes remaining
# 38000 rows completed in 28.23 seconds, estimated 136.11 minutes remaining
# 39000 rows completed in 27.18 seconds, estimated 130.6 minutes remaining
# 40000 rows completed in 25.9 seconds, estimated 124.05 minutes remaining
# 41000 rows completed in 27.17 seconds, estimated 129.68 minutes remaining
# 42000 rows completed in 27.06 seconds, estimated 128.69 minutes remaining
# 43000 rows completed in 26.94 seconds, estimated 127.64 minutes remaining
# 44000 rows completed in 25.3 seconds, estimated 119.48 minutes remaining
# 45000 rows completed in 23.63 seconds, estimated 111.17 minutes remaining
# 46000 rows completed in 26.91 seconds, estimated 126.19 minutes remaining
# 47000 rows completed in 27.2 seconds, estimated 127.07 minutes remaining
# 48000 rows completed in 26.83 seconds, estimated 124.92 minutes remaining
# 49000 rows completed in 33.56 seconds, estimated 155.67 minutes remaining
# 50000 rows completed in 31.32 seconds, estimated 144.78 minutes remaining
# 51000 rows completed in 29.31 seconds, estimated 134.97 minutes remaining
# 52000 rows completed in 32.07 seconds, estimated 147.14 minutes remaining
# 53000 rows completed in 28.06 seconds, estimated 128.29 minutes remaining
# 54000 rows completed in 30.09 seconds, estimated 137.07 minutes remaining
# 55000 rows completed in 28.99 seconds, estimated 131.57 minutes remaining
# 56000 rows completed in 32.03 seconds, estimated 144.84 minutes remaining
# 57000 rows completed in 28.29 seconds, estimated 127.47 minutes remaining
# 58000 rows completed in 30.54 seconds, estimated 137.09 minutes remaining
# 59000 rows completed in 28.6 seconds, estimated 127.88 minutes remaining
# 60000 rows completed in 26.06 seconds, estimated 116.12 minutes remaining
# 61000 rows completed in 26.71 seconds, estimated 118.55 minutes remaining
# 62000 rows completed in 27.72 seconds, estimated 122.59 minutes remaining
# 63000 rows completed in 24.0 seconds, estimated 105.72 minutes remaining
# 64000 rows completed in 25.57 seconds, estimated 112.22 minutes remaining
# 65000 rows completed in 25.49 seconds, estimated 111.44 minutes remaining
# 66000 rows completed in 25.33 seconds, estimated 110.32 minutes remaining
# 67000 rows completed in 23.82 seconds, estimated 103.36 minutes remaining
# 68000 rows completed in 17.19 seconds, estimated 74.3 minutes remaining
# 69000 rows completed in 14.55 seconds, estimated 62.66 minutes remaining
# 70000 rows completed in 17.52 seconds, estimated 75.12 minutes remaining
# 71000 rows completed in 25.48 seconds, estimated 108.83 minutes remaining
# 72000 rows completed in 22.54 seconds, estimated 95.93 minutes remaining
# 73000 rows completed in 31.84 seconds, estimated 134.96 minutes remaining
# 74000 rows completed in 32.94 seconds, estimated 139.06 minutes remaining
# 75000 rows completed in 26.63 seconds, estimated 111.98 minutes remaining
# 76000 rows completed in 27.76 seconds, estimated 116.27 minutes remaining
# 77000 rows completed in 27.97 seconds, estimated 116.68 minutes remaining
# 78000 rows completed in 26.13 seconds, estimated 108.58 minutes remaining
# 79000 rows completed in 22.44 seconds, estimated 92.87 minutes remaining
# 80000 rows completed in 23.82 seconds, estimated 98.2 minutes remaining
# 81000 rows completed in 26.61 seconds, estimated 109.26 minutes remaining
# 82000 rows completed in 25.86 seconds, estimated 105.75 minutes remaining
# 83000 rows completed in 30.72 seconds, estimated 125.09 minutes remaining
# 84000 rows completed in 27.37 seconds, estimated 111.0 minutes remaining
# 85000 rows completed in 25.7 seconds, estimated 103.77 minutes remaining
# 86000 rows completed in 32.44 seconds, estimated 130.49 minutes remaining
# 87000 rows completed in 27.42 seconds, estimated 109.81 minutes remaining
# 88000 rows completed in 27.18 seconds, estimated 108.39 minutes remaining
# 89000 rows completed in 27.96 seconds, estimated 111.06 minutes remaining
# 90000 rows completed in 29.83 seconds, estimated 117.97 minutes remaining
# 91000 rows completed in 29.31 seconds, estimated 115.46 minutes remaining
# 92000 rows completed in 27.8 seconds, estimated 109.03 minutes remaining
# 93000 rows completed in 27.74 seconds, estimated 108.33 minutes remaining
# 94000 rows completed in 26.88 seconds, estimated 104.54 minutes remaining
# 95000 rows completed in 27.83 seconds, estimated 107.75 minutes remaining
# 96000 rows completed in 28.91 seconds, estimated 111.44 minutes remaining
# 97000 rows completed in 27.32 seconds, estimated 104.86 minutes remaining
# 98000 rows completed in 28.1 seconds, estimated 107.39 minutes remaining
# 99000 rows completed in 27.07 seconds, estimated 102.99 minutes remaining
# 100000 rows completed in 27.17 seconds, estimated 102.94 minutes remaining
# 101000 rows completed in 27.28 seconds, estimated 102.9 minutes remaining
# 102000 rows completed in 27.75 seconds, estimated 104.2 minutes remaining
# 103000 rows completed in 27.12 seconds, estimated 101.41 minutes remaining
# 104000 rows completed in 27.21 seconds, estimated 101.28 minutes remaining
# 105000 rows completed in 27.08 seconds, estimated 100.34 minutes remaining
# 106000 rows completed in 27.0 seconds, estimated 99.6 minutes remaining
# 107000 rows completed in 27.82 seconds, estimated 102.16 minutes remaining
# 108000 rows completed in 27.51 seconds, estimated 100.55 minutes remaining
# 109000 rows completed in 27.6 seconds, estimated 100.42 minutes remaining
# 110000 rows completed in 29.09 seconds, estimated 105.35 minutes remaining
# 111000 rows completed in 29.3 seconds, estimated 105.62 minutes remaining
# 112000 rows completed in 28.18 seconds, estimated 101.12 minutes remaining
# 113000 rows completed in 27.6 seconds, estimated 98.6 minutes remaining
# 114000 rows completed in 26.93 seconds, estimated 95.73 minutes remaining
# 115000 rows completed in 27.01 seconds, estimated 95.56 minutes remaining
# 116000 rows completed in 27.22 seconds, estimated 95.87 minutes remaining
# 117000 rows completed in 24.95 seconds, estimated 87.47 minutes remaining
# 118000 rows completed in 26.78 seconds, estimated 93.43 minutes remaining
# 119000 rows completed in 27.44 seconds, estimated 95.26 minutes remaining
# 120000 rows completed in 28.78 seconds, estimated 99.44 minutes remaining
# 121000 rows completed in 29.76 seconds, estimated 102.33 minutes remaining
# 122000 rows completed in 24.52 seconds, estimated 83.9 minutes remaining
# 123000 rows completed in 29.47 seconds, estimated 100.36 minutes remaining
# 124000 rows completed in 27.67 seconds, estimated 93.78 minutes remaining
# 125000 rows completed in 28.76 seconds, estimated 96.96 minutes remaining
# 126000 rows completed in 28.74 seconds, estimated 96.45 minutes remaining
# 127000 rows completed in 28.4 seconds, estimated 94.82 minutes remaining
# 128000 rows completed in 33.09 seconds, estimated 109.92 minutes remaining
# 129000 rows completed in 29.06 seconds, estimated 96.04 minutes remaining
# 130000 rows completed in 28.6 seconds, estimated 94.04 minutes remaining
# 131000 rows completed in 29.09 seconds, estimated 95.19 minutes remaining
# 132000 rows completed in 29.03 seconds, estimated 94.52 minutes remaining
# 133000 rows completed in 28.86 seconds, estimated 93.46 minutes remaining
# 134000 rows completed in 27.6 seconds, estimated 88.94 minutes remaining
# 135000 rows completed in 27.62 seconds, estimated 88.53 minutes remaining
# 136000 rows completed in 27.45 seconds, estimated 87.53 minutes remaining
# 137000 rows completed in 28.36 seconds, estimated 89.95 minutes remaining
# 138000 rows completed in 28.59 seconds, estimated 90.2 minutes remaining
# 139000 rows completed in 28.0 seconds, estimated 87.88 minutes remaining
# 140000 rows completed in 27.54 seconds, estimated 85.98 minutes remaining
# 141000 rows completed in 27.5 seconds, estimated 85.39 minutes remaining
# 142000 rows completed in 26.08 seconds, estimated 80.56 minutes remaining
# 143000 rows completed in 27.58 seconds, estimated 84.72 minutes remaining
# 144000 rows completed in 27.51 seconds, estimated 84.05 minutes remaining
# 145000 rows completed in 25.77 seconds, estimated 78.31 minutes remaining
# 146000 rows completed in 27.43 seconds, estimated 82.9 minutes remaining
# 147000 rows completed in 27.27 seconds, estimated 81.94 minutes remaining
# 148000 rows completed in 27.39 seconds, estimated 81.85 minutes remaining
# 149000 rows completed in 27.68 seconds, estimated 82.27 minutes remaining
# 150000 rows completed in 27.0 seconds, estimated 79.78 minutes remaining
# 151000 rows completed in 27.46 seconds, estimated 80.7 minutes remaining
# 152000 rows completed in 28.03 seconds, estimated 81.91 minutes remaining
# 153000 rows completed in 28.14 seconds, estimated 81.77 minutes remaining
# 154000 rows completed in 25.88 seconds, estimated 74.77 minutes remaining
# 155000 rows completed in 27.4 seconds, estimated 78.7 minutes remaining
# 156000 rows completed in 27.42 seconds, estimated 78.29 minutes remaining
# 157000 rows completed in 25.26 seconds, estimated 71.71 minutes remaining
# 158000 rows completed in 28.31 seconds, estimated 79.89 minutes remaining
# 159000 rows completed in 27.35 seconds, estimated 76.72 minutes remaining
# 160000 rows completed in 27.33 seconds, estimated 76.22 minutes remaining
# 161000 rows completed in 26.9 seconds, estimated 74.55 minutes remaining
# 162000 rows completed in 27.37 seconds, estimated 75.42 minutes remaining
# 163000 rows completed in 27.53 seconds, estimated 75.39 minutes remaining
# 164000 rows completed in 27.55 seconds, estimated 74.99 minutes remaining
# 165000 rows completed in 27.57 seconds, estimated 74.6 minutes remaining
# 166000 rows completed in 27.59 seconds, estimated 74.18 minutes remaining
# 167000 rows completed in 27.7 seconds, estimated 74.0 minutes remaining
# 168000 rows completed in 27.55 seconds, estimated 73.16 minutes remaining
# 169000 rows completed in 27.72 seconds, estimated 73.13 minutes remaining
# 170000 rows completed in 27.57 seconds, estimated 72.28 minutes remaining
# 171000 rows completed in 27.59 seconds, estimated 71.88 minutes remaining
# 172000 rows completed in 27.58 seconds, estimated 71.4 minutes remaining
# 173000 rows completed in 27.61 seconds, estimated 71.01 minutes remaining
# 174000 rows completed in 27.76 seconds, estimated 70.93 minutes remaining
# 175000 rows completed in 27.52 seconds, estimated 69.85 minutes remaining
# 176000 rows completed in 27.63 seconds, estimated 69.67 minutes remaining
# 177000 rows completed in 27.52 seconds, estimated 68.96 minutes remaining
# 178000 rows completed in 27.55 seconds, estimated 68.56 minutes remaining
# 179000 rows completed in 27.26 seconds, estimated 67.4 minutes remaining
# 180000 rows completed in 27.55 seconds, estimated 67.65 minutes remaining
# 181000 rows completed in 27.36 seconds, estimated 66.73 minutes remaining
# 182000 rows completed in 27.8 seconds, estimated 67.33 minutes remaining
# 183000 rows completed in 566.91 seconds, estimated 1363.61 minutes remaining
# 184000 rows completed in 26.34 seconds, estimated 62.93 minutes remaining
# 185000 rows completed in 28.36 seconds, estimated 67.28 minutes remaining
# 186000 rows completed in 28.01 seconds, estimated 65.98 minutes remaining
# 187000 rows completed in 32.7 seconds, estimated 76.47 minutes remaining
# 188000 rows completed in 18.2 seconds, estimated 42.27 minutes remaining
# 189000 rows completed in 29.51 seconds, estimated 68.02 minutes remaining
# 190000 rows completed in 29.27 seconds, estimated 67.0 minutes remaining
# 191000 rows completed in 27.64 seconds, estimated 62.81 minutes remaining
# 192000 rows completed in 28.16 seconds, estimated 63.5 minutes remaining
# 193000 rows completed in 30.16 seconds, estimated 67.53 minutes remaining
# 194000 rows completed in 31.15 seconds, estimated 69.2 minutes remaining
# 195000 rows completed in 26.5 seconds, estimated 58.43 minutes remaining
# 196000 rows completed in 29.53 seconds, estimated 64.64 minutes remaining
# 197000 rows completed in 29.7 seconds, estimated 64.5 minutes remaining
# 198000 rows completed in 28.49 seconds, estimated 61.41 minutes remaining
# 199000 rows completed in 29.27 seconds, estimated 62.59 minutes remaining
# 200000 rows completed in 26.83 seconds, estimated 56.94 minutes remaining
# 201000 rows completed in 29.42 seconds, estimated 61.93 minutes remaining
# 202000 rows completed in 29.72 seconds, estimated 62.08 minutes remaining
# 203000 rows completed in 30.12 seconds, estimated 62.4 minutes remaining
# 204000 rows completed in 27.78 seconds, estimated 57.1 minutes remaining
# 205000 rows completed in 27.55 seconds, estimated 56.16 minutes remaining
# 206000 rows completed in 29.82 seconds, estimated 60.3 minutes remaining
# 207000 rows completed in 30.4 seconds, estimated 60.97 minutes remaining
# 208000 rows completed in 27.8 seconds, estimated 55.27 minutes remaining
# 209000 rows completed in 29.09 seconds, estimated 57.36 minutes remaining
# 210000 rows completed in 27.51 seconds, estimated 53.8 minutes remaining
# 211000 rows completed in 26.37 seconds, estimated 51.11 minutes remaining
# 212000 rows completed in 27.65 seconds, estimated 53.15 minutes remaining
# 213000 rows completed in 28.49 seconds, estimated 54.28 minutes remaining
# 214000 rows completed in 27.39 seconds, estimated 51.73 minutes remaining
# 215000 rows completed in 26.8 seconds, estimated 50.16 minutes remaining
# 216000 rows completed in 24.4 seconds, estimated 45.27 minutes remaining
# 217000 rows completed in 24.5 seconds, estimated 45.04 minutes remaining
# 218000 rows completed in 30.84 seconds, estimated 56.18 minutes remaining
# 219000 rows completed in 27.9 seconds, estimated 50.38 minutes remaining
# 220000 rows completed in 26.24 seconds, estimated 46.93 minutes remaining
# 221000 rows completed in 25.38 seconds, estimated 44.98 minutes remaining
# 222000 rows completed in 27.09 seconds, estimated 47.56 minutes remaining
# 223000 rows completed in 26.07 seconds, estimated 45.32 minutes remaining
# 224000 rows completed in 27.56 seconds, estimated 47.46 minutes remaining
# 225000 rows completed in 26.26 seconds, estimated 44.79 minutes remaining
# 226000 rows completed in 28.21 seconds, estimated 47.63 minutes remaining
# 227000 rows completed in 25.69 seconds, estimated 42.96 minutes remaining
# 228000 rows completed in 29.6 seconds, estimated 49.0 minutes remaining
# 229000 rows completed in 28.28 seconds, estimated 46.35 minutes remaining
# 230000 rows completed in 28.15 seconds, estimated 45.66 minutes remaining
# 231000 rows completed in 25.62 seconds, estimated 41.12 minutes remaining
# 232000 rows completed in 27.37 seconds, estimated 43.49 minutes remaining
# 233000 rows completed in 28.24 seconds, estimated 44.4 minutes remaining
# 234000 rows completed in 29.52 seconds, estimated 45.91 minutes remaining
# 235000 rows completed in 27.44 seconds, estimated 42.22 minutes remaining
# 236000 rows completed in 29.09 seconds, estimated 44.28 minutes remaining
# 237000 rows completed in 29.56 seconds, estimated 44.5 minutes remaining
# 238000 rows completed in 28.05 seconds, estimated 41.75 minutes remaining
# 239000 rows completed in 27.96 seconds, estimated 41.16 minutes remaining
# 240000 rows completed in 29.77 seconds, estimated 43.32 minutes remaining
# 241000 rows completed in 29.83 seconds, estimated 42.91 minutes remaining
# 242000 rows completed in 30.22 seconds, estimated 42.97 minutes remaining
# 243000 rows completed in 29.51 seconds, estimated 41.47 minutes remaining
# 244000 rows completed in 28.21 seconds, estimated 39.17 minutes remaining
# 245000 rows completed in 28.77 seconds, estimated 39.47 minutes remaining
# 246000 rows completed in 27.0 seconds, estimated 36.6 minutes remaining
# 247000 rows completed in 29.17 seconds, estimated 39.05 minutes remaining
# 248000 rows completed in 29.25 seconds, estimated 38.67 minutes remaining
# 249000 rows completed in 30.19 seconds, estimated 39.41 minutes remaining
# 250000 rows completed in 26.79 seconds, estimated 34.52 minutes remaining
# 251000 rows completed in 27.82 seconds, estimated 35.39 minutes remaining
# 252000 rows completed in 26.52 seconds, estimated 33.29 minutes remaining
# 253000 rows completed in 23.9 seconds, estimated 29.6 minutes remaining
# 254000 rows completed in 27.65 seconds, estimated 33.79 minutes remaining
# 255000 rows completed in 26.75 seconds, estimated 32.24 minutes remaining
# 256000 rows completed in 26.33 seconds, estimated 31.3 minutes remaining
# 257000 rows completed in 27.58 seconds, estimated 32.33 minutes remaining
# 258000 rows completed in 24.35 seconds, estimated 28.13 minutes remaining
# 259000 rows completed in 26.94 seconds, estimated 30.67 minutes remaining
# 260000 rows completed in 28.45 seconds, estimated 31.92 minutes remaining
# 261000 rows completed in 28.88 seconds, estimated 31.93 minutes remaining
# 262000 rows completed in 26.97 seconds, estimated 29.36 minutes remaining
# 263000 rows completed in 23.14 seconds, estimated 24.8 minutes remaining
# 264000 rows completed in 28.1 seconds, estimated 29.66 minutes remaining
# 265000 rows completed in 27.7 seconds, estimated 28.77 minutes remaining
# 266000 rows completed in 28.26 seconds, estimated 28.88 minutes remaining
# 267000 rows completed in 25.91 seconds, estimated 26.05 minutes remaining
# 268000 rows completed in 28.44 seconds, estimated 28.12 minutes remaining
# 269000 rows completed in 27.76 seconds, estimated 26.99 minutes remaining
# 270000 rows completed in 28.37 seconds, estimated 27.11 minutes remaining
# 271000 rows completed in 30.4 seconds, estimated 28.53 minutes remaining
# 272000 rows completed in 29.53 seconds, estimated 27.23 minutes remaining
# 273000 rows completed in 29.08 seconds, estimated 26.32 minutes remaining
# 274000 rows completed in 29.08 seconds, estimated 25.84 minutes remaining
# 275000 rows completed in 25.68 seconds, estimated 22.39 minutes remaining
# 276000 rows completed in 27.32 seconds, estimated 23.36 minutes remaining
# 277000 rows completed in 27.27 seconds, estimated 22.87 minutes remaining
# 278000 rows completed in 34.94 seconds, estimated 28.72 minutes remaining
# 279000 rows completed in 29.07 seconds, estimated 23.41 minutes remaining
# 280000 rows completed in 27.96 seconds, estimated 22.05 minutes remaining
# 281000 rows completed in 28.54 seconds, estimated 22.03 minutes remaining
# 282000 rows completed in 28.04 seconds, estimated 21.18 minutes remaining
# 283000 rows completed in 27.51 seconds, estimated 20.32 minutes remaining
# 284000 rows completed in 26.5 seconds, estimated 19.14 minutes remaining
# 285000 rows completed in 26.0 seconds, estimated 18.34 minutes remaining
# 286000 rows completed in 28.29 seconds, estimated 19.48 minutes remaining
# 287000 rows completed in 30.71 seconds, estimated 20.63 minutes remaining
# 288000 rows completed in 29.16 seconds, estimated 19.11 minutes remaining
# 289000 rows completed in 26.87 seconds, estimated 17.16 minutes remaining
# 290000 rows completed in 28.09 seconds, estimated 17.47 minutes remaining
# 291000 rows completed in 26.9 seconds, estimated 16.28 minutes remaining
# 292000 rows completed in 27.43 seconds, estimated 16.15 minutes remaining
# 293000 rows completed in 27.24 seconds, estimated 15.58 minutes remaining
# 294000 rows completed in 28.63 seconds, estimated 15.9 minutes remaining
# 295000 rows completed in 28.44 seconds, estimated 15.32 minutes remaining
# 296000 rows completed in 27.18 seconds, estimated 14.19 minutes remaining
# 297000 rows completed in 24.51 seconds, estimated 12.38 minutes remaining
# 298000 rows completed in 26.69 seconds, estimated 13.04 minutes remaining
# 299000 rows completed in 24.85 seconds, estimated 11.73 minutes remaining
# 300000 rows completed in 25.74 seconds, estimated 11.72 minutes remaining
# 301000 rows completed in 28.62 seconds, estimated 12.55 minutes remaining
# 302000 rows completed in 26.96 seconds, estimated 11.38 minutes remaining
# 303000 rows completed in 26.59 seconds, estimated 10.78 minutes remaining
# 304000 rows completed in 27.22 seconds, estimated 10.58 minutes remaining
# 305000 rows completed in 28.03 seconds, estimated 10.43 minutes remaining
# 306000 rows completed in 25.89 seconds, estimated 9.2 minutes remaining
# 307000 rows completed in 27.37 seconds, estimated 9.27 minutes remaining
# 308000 rows completed in 32.07 seconds, estimated 10.33 minutes remaining
# 309000 rows completed in 28.76 seconds, estimated 8.78 minutes remaining
# 310000 rows completed in 28.76 seconds, estimated 8.3 minutes remaining
# 311000 rows completed in 29.7 seconds, estimated 8.08 minutes remaining
# 312000 rows completed in 31.12 seconds, estimated 7.94 minutes remaining
# 313000 rows completed in 28.92 seconds, estimated 6.9 minutes remaining
# 314000 rows completed in 33.06 seconds, estimated 7.34 minutes remaining
# 315000 rows completed in 28.24 seconds, estimated 5.8 minutes remaining
# 316000 rows completed in 33.65 seconds, estimated 6.35 minutes remaining
# 317000 rows completed in 34.96 seconds, estimated 6.01 minutes remaining
# 318000 rows completed in 29.24 seconds, estimated 4.54 minutes remaining
# 319000 rows completed in 40.87 seconds, estimated 5.67 minutes remaining
# 320000 rows completed in 31.35 seconds, estimated 3.82 minutes remaining
# 321000 rows completed in 28.66 seconds, estimated 3.02 minutes remaining
# 322000 rows completed in 35.73 seconds, estimated 3.17 minutes remaining
# 323000 rows completed in 39.14 seconds, estimated 2.82 minutes remaining
# 324000 rows completed in 42.52 seconds, estimated 2.35 minutes remaining
# 325000 rows completed in 36.12 seconds, estimated 1.4 minutes remaining
# 326000 rows completed in 27.07 seconds, estimated 0.6 minutes remaining
# 327000 rows completed in 26.31 seconds, estimated 0.14 minutes remaining
#
# Completed 327319 rows in 160.92 minutes

# %%
df["at_risk"].value_counts()
# Out:
# False    327319
# Name: at_risk, dtype: int64
